# %%
from matplotlib import pyplot as plt
import cv2

# %%
def sketch_transform(image):
    image_grayscale = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image_grayscale_blurred = cv2.GaussianBlur(image_grayscale, (7,7), 0)
    
    return image_grayscale_blurred

# %%
cam_capture = cv2.VideoCapture(0)
cv2.destroyAllWindows()
upper_left = (50, 50)
bottom_right = (300, 300)
while True:
    _, image_frame = cam_capture.read()
    
    #Rectangle marker
    r = cv2.rectangle(image_frame, upper_left, bottom_right, (255,0,0), 2)
    rect_img = image_frame[upper_left[1] : bottom_right[1], upper_left[0] : bottom_right[0]]
    
    transform=sketch_transform(rect_img)
    text = 'Hello'
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(image_frame,text, (50, 50),  font, 1, (0, 0 ,255), 2,cv2.LINE_AA) 
    cv2.imshow("Frame", image_frame)
    cv2.imshow("cropped", transform)
    
    if cv2.waitKey(1) == 13:
        break
        
cam_capture.release()
cv2.destroyAllWindows()

# %%
img=cv2.imread('/home/siddharth/Pictures/sample.png')
plt.imshow(img)

# %%
img2=cv2.resize(img,(64,64))
plt.imshow(img2)
